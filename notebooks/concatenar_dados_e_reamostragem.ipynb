# %% [markdown]
# ## Desafio ENACOM - Bootcamp Seletivo Data Analytics 2024
# Concatenação e reamostragem dos dados do ONS
#
# Desenvolvido por: Gustavo Basílio Lima
#
# Import das bibliotecas utilizadas ao decorrer do notebook

# %%
import pandas as pd
import dask.dataframe as dd
import numpy as np
import glob
import os
# Out:
# C:\Users\gusta\AppData\Local\Temp\ipykernel_17272\2042893738.py:4: DeprecationWarning: The current Dask DataFrame implementation is deprecated.
# In a future release, Dask DataFrame will use a new implementation that
# contains several improvements including a logical query planning.
# The user-facing DataFrame API will remain unchanged.
#
# The new implementation is already available and can be enabled by
# installing the dask-expr library:
#
#     $ pip install dask-expr
#
# and turning the query planning option on:
#
#     >>> import dask
#     >>> dask.config.set({'dataframe.query-planning': True})
#     >>> import dask.dataframe as dd
#
# API documentation for the new implementation is available at
# https://docs.dask.org/en/stable/dask-expr-api.html
#
# Any feedback can be reported on the Dask issue tracker
# https://github.com/dask/dask/issues
#
# To disable this warning in the future, set dask config:
#
#     # via Python
#     >>> dask.config.set({'dataframe.query-planning-warning': False})
#
#     # via CLI
#     dask config set dataframe.query-planning-warning False
#
#
#   import dask.dataframe as dd

# %% [markdown]
# ## Concatenação dos dados
#
# Com os arquivos baixados do https://dados.ons.org.br/dataset/geracao-usina-2 e alocados em uma única pasta, é realizada a varredura para a concatenação.
# 1. É criada uma lista com os paths dos arquivos no formato .csv;
# 2. Os arquivos em .csv são lidos como dataframe, e assim concatenados pelas suas colunas;
# 3. Por fim, definidos os index como a marcação de DateTime.

# %%
list_path = []
for file in glob.glob(r'..\dados\ons\*'):
    list_path.append(os.path.abspath(file))
    
df_all_data = pd.DataFrame()
for path in list_path:
    df_all_data = pd.concat([df_all_data, pd.read_csv(path, sep=';', parse_dates=['din_instante'], index_col='din_instante')], axis=0)

df_all_data.index = pd.to_datetime(df_all_data.index)
df_all_data
# Out:
#                     id_subsistema nom_subsistema id_estado nom_estado  \
# din_instante
# 2000-01-01 00:00:00             N          NORTE        PA       PARA
# 2000-01-01 00:00:00            NE       NORDESTE        AL    ALAGOAS
# 2000-01-01 00:00:00            NE       NORDESTE        BA      BAHIA
# 2000-01-01 00:00:00            NE       NORDESTE        BA      BAHIA
# 2000-01-01 00:00:00            NE       NORDESTE        BA      BAHIA
# ...                           ...            ...       ...        ...
# 2021-12-31 23:00:00            SE        SUDESTE        SP  SAO PAULO
# 2021-12-31 23:00:00            SE        SUDESTE        SP  SAO PAULO
# 2021-12-31 23:00:00            SE        SUDESTE        TO  TOCANTINS
# 2021-12-31 23:00:00            SE        SUDESTE        TO  TOCANTINS
# 2021-12-31 23:00:00            SE        SUDESTE        TO  TOCANTINS
#
#                          cod_modalidadeoperacao  nom_tipousina  \
# din_instante
# 2000-01-01 00:00:00                      TIPO I  HIDROELÉTRICA
# 2000-01-01 00:00:00                      TIPO I  HIDROELÉTRICA
# 2000-01-01 00:00:00  Pequenas Usinas (Tipo III)  HIDROELÉTRICA
# 2000-01-01 00:00:00                      TIPO I  HIDROELÉTRICA
# 2000-01-01 00:00:00                      TIPO I  HIDROELÉTRICA
# ...                                         ...            ...
# 2021-12-31 23:00:00                      TIPO I        TÉRMICA
# 2021-12-31 23:00:00  Pequenas Usinas (Tipo III)        TÉRMICA
# 2021-12-31 23:00:00                      TIPO I  HIDROELÉTRICA
# 2021-12-31 23:00:00                      TIPO I  HIDROELÉTRICA
# 2021-12-31 23:00:00                      TIPO I  HIDROELÉTRICA
#
#                           nom_tipocombustivel  \
# din_instante
# 2000-01-01 00:00:00                Hidráulica
# 2000-01-01 00:00:00                Hidráulica
# 2000-01-01 00:00:00                Hidráulica
# 2000-01-01 00:00:00                Hidráulica
# 2000-01-01 00:00:00                Hidráulica
# ...                                       ...
# 2021-12-31 23:00:00                       Gás
# 2021-12-31 23:00:00  Outras Multi-Combustível
# 2021-12-31 23:00:00                Hidráulica
# 2021-12-31 23:00:00                Hidráulica
# 2021-12-31 23:00:00                Hidráulica
#
#                                                      nom_usina  \
# din_instante
# 2000-01-01 00:00:00                                    Tucuruí
# 2000-01-01 00:00:00                                      Xingó
# 2000-01-01 00:00:00  Pequenas Centrais Hidroelétricas da Chesf
# 2000-01-01 00:00:00                             Apolônio Sales
# 2000-01-01 00:00:00                            Paulo Afonso II
# ...                                                        ...
# 2021-12-31 23:00:00                           Nova Piratininga
# 2021-12-31 23:00:00               PQU SPSP TERM - CARGA GLOBAL
# 2021-12-31 23:00:00                               São Salvador
# 2021-12-31 23:00:00                                    Lajeado
# 2021-12-31 23:00:00                              Peixe Angical
#
#                                        ceg  val_geracao id_ons
# din_instante
# 2000-01-01 00:00:00  UHE.PH.PA.002889-4.01     2422.500    NaN
# 2000-01-01 00:00:00  UHE.PH.SE.027053-9.01     1995.600    NaN
# 2000-01-01 00:00:00                      -       13.000    NaN
# 2000-01-01 00:00:00  UHE.PH.AL.001510-5.01      202.500    NaN
# 2000-01-01 00:00:00  UHE.PH.BA.027048-2.01      269.800    NaN
# ...                                    ...          ...    ...
# 2021-12-31 23:00:00  UTE.GN.SP.028191-3.01        0.000    NaN
# 2021-12-31 23:00:00                      -      147.000    NaN
# 2021-12-31 23:00:00  UHE.PH.TO.028567-6.01      233.109    NaN
# 2021-12-31 23:00:00  UHE.PH.TO.001304-8.01      584.262    NaN
# 2021-12-31 23:00:00  UHE.PH.TO.028353-3.01      420.073    NaN
#
# [59203587 rows x 11 columns]

# %% [markdown]
# ## Upload dos dados concatenados
#
# Devido ao alto número de linhas, na forma que o dataframe está, é decidido exportá-lo no formato .parquet para melhorar o processamento dos dados em um momente de leitura posterior.

# %%
df_all_data.to_parquet(r'..\dados\concatenado\df_all_data.parquet')

# %% [markdown]
# ## Comparação entre pandas e dask
#
# Além disso, para melhorar no processamento dos dados, é decidido utilizar a biblioteca dask, pois como pode ser visto, o tempo de processamento para uma leitura de arquivos de dados é reduzido quando comparado ao pandas.

# %%
# %time pandas_df_all_data = pd.read_parquet(r'..\dados\concatenado\df_all_data.parquet')
# Out:
# CPU times: total: 49.3 s
# Wall time: 1min 19s

# %%
# %time dask_df_all_data = dd.read_parquet(r'..\dados\concatenado\df_all_data.parquet')
# Out:
# CPU times: total: 31.2 ms
# Wall time: 281 ms

# %% [markdown]
# ## Carregamentos dos dados
#
# Realizada a leitura dos dados, é utilizado a função .compute() para o dataframe oriundo da biblioteca dask possa ser trabalhado com as mesmas funções do pandas. Em seguinda, é definido o index do dataframe a partir das marcações de tempo DateTime.

# %%
dask_df_all_data = dd.read_parquet(r'..\dados\concatenado\df_all_data.parquet')

# %%
dask_df_all_data = dask_df_all_data.compute()
dask_df_all_data.index = pd.to_datetime(dask_df_all_data.index, format='%Y-%m-%d %H:%M:%S')
dask_df_all_data
# Out:
#                     id_subsistema nom_subsistema id_estado nom_estado  \
# din_instante
# 2000-01-01 00:00:00             N          NORTE        PA       PARA
# 2000-01-01 00:00:00            NE       NORDESTE        AL    ALAGOAS
# 2000-01-01 00:00:00            NE       NORDESTE        BA      BAHIA
# 2000-01-01 00:00:00            NE       NORDESTE        BA      BAHIA
# 2000-01-01 00:00:00            NE       NORDESTE        BA      BAHIA
# ...                           ...            ...       ...        ...
# 2021-12-31 23:00:00            SE        SUDESTE        SP  SAO PAULO
# 2021-12-31 23:00:00            SE        SUDESTE        SP  SAO PAULO
# 2021-12-31 23:00:00            SE        SUDESTE        TO  TOCANTINS
# 2021-12-31 23:00:00            SE        SUDESTE        TO  TOCANTINS
# 2021-12-31 23:00:00            SE        SUDESTE        TO  TOCANTINS
#
#                          cod_modalidadeoperacao  nom_tipousina  \
# din_instante
# 2000-01-01 00:00:00                      TIPO I  HIDROELÉTRICA
# 2000-01-01 00:00:00                      TIPO I  HIDROELÉTRICA
# 2000-01-01 00:00:00  Pequenas Usinas (Tipo III)  HIDROELÉTRICA
# 2000-01-01 00:00:00                      TIPO I  HIDROELÉTRICA
# 2000-01-01 00:00:00                      TIPO I  HIDROELÉTRICA
# ...                                         ...            ...
# 2021-12-31 23:00:00                      TIPO I        TÉRMICA
# 2021-12-31 23:00:00  Pequenas Usinas (Tipo III)        TÉRMICA
# 2021-12-31 23:00:00                      TIPO I  HIDROELÉTRICA
# 2021-12-31 23:00:00                      TIPO I  HIDROELÉTRICA
# 2021-12-31 23:00:00                      TIPO I  HIDROELÉTRICA
#
#                           nom_tipocombustivel  \
# din_instante
# 2000-01-01 00:00:00                Hidráulica
# 2000-01-01 00:00:00                Hidráulica
# 2000-01-01 00:00:00                Hidráulica
# 2000-01-01 00:00:00                Hidráulica
# 2000-01-01 00:00:00                Hidráulica
# ...                                       ...
# 2021-12-31 23:00:00                       Gás
# 2021-12-31 23:00:00  Outras Multi-Combustível
# 2021-12-31 23:00:00                Hidráulica
# 2021-12-31 23:00:00                Hidráulica
# 2021-12-31 23:00:00                Hidráulica
#
#                                                      nom_usina  \
# din_instante
# 2000-01-01 00:00:00                                    Tucuruí
# 2000-01-01 00:00:00                                      Xingó
# 2000-01-01 00:00:00  Pequenas Centrais Hidroelétricas da Chesf
# 2000-01-01 00:00:00                             Apolônio Sales
# 2000-01-01 00:00:00                            Paulo Afonso II
# ...                                                        ...
# 2021-12-31 23:00:00                           Nova Piratininga
# 2021-12-31 23:00:00               PQU SPSP TERM - CARGA GLOBAL
# 2021-12-31 23:00:00                               São Salvador
# 2021-12-31 23:00:00                                    Lajeado
# 2021-12-31 23:00:00                              Peixe Angical
#
#                                        ceg  val_geracao id_ons
# din_instante
# 2000-01-01 00:00:00  UHE.PH.PA.002889-4.01     2422.500   <NA>
# 2000-01-01 00:00:00  UHE.PH.SE.027053-9.01     1995.600   <NA>
# 2000-01-01 00:00:00                      -       13.000   <NA>
# 2000-01-01 00:00:00  UHE.PH.AL.001510-5.01      202.500   <NA>
# 2000-01-01 00:00:00  UHE.PH.BA.027048-2.01      269.800   <NA>
# ...                                    ...          ...    ...
# 2021-12-31 23:00:00  UTE.GN.SP.028191-3.01        0.000   <NA>
# 2021-12-31 23:00:00                      -      147.000   <NA>
# 2021-12-31 23:00:00  UHE.PH.TO.028567-6.01      233.109   <NA>
# 2021-12-31 23:00:00  UHE.PH.TO.001304-8.01      584.262   <NA>
# 2021-12-31 23:00:00  UHE.PH.TO.028353-3.01      420.073   <NA>
#
# [59203587 rows x 11 columns]

# %% [markdown]
# ## Exclusão de colunas
#
# Com o objetivo de realizar uma análise de geração de energia elétrica segmentada pelas fontes de obtenção, algumas colunas do dataframe original são descartadas, algumas consideradas redundantes, como siglas de região, estado, modalidade de operação da usina, código e nome do empreendimento.

# %%
droped_columns_dask_df_all_data = dask_df_all_data.drop(columns=['id_subsistema', 'id_estado', 'cod_modalidadeoperacao', 'ceg', 'id_ons', 'val_geracao'])
droped_columns_dask_df_all_data.columns
# Out:
# Index(['nom_subsistema', 'nom_estado', 'nom_tipousina', 'nom_tipocombustivel',
#        'nom_usina'],
#       dtype='object')

# %% [markdown]
# ## Reasmostragem dos dados
#
# Conforme a taxa de amostragem dos dados desse desafio é diferente da taxa dos dados do ONS, então é realizado esse processo com a função .resample() para que os dados sejam utilizados de forma mensal.
#
# Agrupados pelas colunas de subsistime, estado, tipo de usina, tipo de combustível e nome da usina, os valores da geração são integrados.

# %%
resampled_dask_df_all_data = dask_df_all_data.groupby(list(droped_columns_dask_df_all_data.columns), group_keys=True)[['val_geracao']].resample('M', kind='period').sum()
resampled_dask_df_all_data = resampled_dask_df_all_data.sort_values('din_instante',ascending=True).reset_index()
resampled_dask_df_all_data.index = resampled_dask_df_all_data.pop('din_instante')
resampled_dask_df_all_data
# Out:
#              nom_subsistema          nom_estado  nom_tipousina  \
# din_instante
# 2000-01             SUDESTE           SAO PAULO  HIDROELÉTRICA
# 2000-01                 SUL              PARANA  HIDROELÉTRICA
# 2000-01             SUDESTE        MINAS GERAIS  HIDROELÉTRICA
# 2000-01             SUDESTE        MINAS GERAIS  HIDROELÉTRICA
# 2000-01             SUDESTE  MATO GROSSO DO SUL        TÉRMICA
# ...                     ...                 ...            ...
# 2021-12            NORDESTE               BAHIA  HIDROELÉTRICA
# 2021-12             SUDESTE               GOIAS  HIDROELÉTRICA
# 2021-12             SUDESTE               GOIAS  HIDROELÉTRICA
# 2021-12             SUDESTE               GOIAS  HIDROELÉTRICA
# 2021-12                 SUL      SANTA CATARINA        TÉRMICA
#
#                    nom_tipocombustivel                     nom_usina  \
# din_instante
# 2000-01                     Hidráulica                       Caconde
# 2000-01                     Hidráulica                Gov. Ney Braga
# 2000-01                     Hidráulica                     Itumbiara
# 2000-01                     Hidráulica                       Sobragi
# 2000-01                            Gás                Willian Arjona
# ...                                ...                           ...
# 2021-12                     Hidráulica                Paulo Afonso I
# 2021-12                     Hidráulica                Serra do Facão
# 2021-12                     Hidráulica                       Verde 8
# 2021-12                     Hidráulica   PQU MTGO HID - CARGA GLOBAL
# 2021-12       Outras Multi-Combustível  PQU SCSC TERM - CARGA GLOBAL
#
#               val_geracao
# din_instante
# 2000-01         23880.900
# 2000-01        374162.300
# 2000-01        574602.300
# 2000-01         33558.400
# 2000-01             0.000
# ...                   ...
# 2021-12           543.451
# 2021-12         37375.320
# 2021-12         10548.214
# 2021-12             0.000
# 2021-12         13033.937
#
# [87218 rows x 6 columns]

# %% [markdown]
# ## Upload dos dados reamostrados
#
# Por fim, os dados concatenados e reamostrados são exportados no formato .parquet para análises futuras.

# %%
resampled_dask_df_all_data.to_parquet(r'..\dados\deamostrados\resampled_dask_df_all_data.parquet')
